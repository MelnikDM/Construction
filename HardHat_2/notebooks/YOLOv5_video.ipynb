# %% [markdown]
# ## Загружаем необходимые библиотеки

# %%
import os

import random
import pandas as pd
import numpy as np
import shutil
from tqdm import tqdm

import matplotlib
import plotly
import PIL
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

import yaml
import torch
import json
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET

from sklearn.model_selection import train_test_split

# %% [markdown]
# Загрузка YOLO5

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16103, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16103 (delta 4), reused 4 (delta 0), pack-reused 16089
# Receiving objects: 100% (16103/16103), 14.77 MiB | 19.62 MiB/s, done.
# Resolving deltas: 100% (11028/11028), done.
# /content/yolov5

# %%
# %cd /content/yolov5

# !pip install -qr requirements.txt
# !pip install -q roboflow
# Out:
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 58.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Загрузка датасета

# %%
# !git clone 'https://github.com/MelnikDM/Construction.git'
# Out:
# Cloning into 'Construction'...
# remote: Enumerating objects: 19861, done.
# remote: Counting objects: 100% (6301/6301), done.
# remote: Compressing objects: 100% (3429/3429), done.
# remote: Total 19861 (delta 2872), reused 6294 (delta 2865), pack-reused 13560
# Receiving objects: 100% (19861/19861), 1.45 GiB | 41.34 MiB/s, done.
# Resolving deltas: 100% (9799/9799), done.
# Updating files: 100% (4615/4615), done.

# %%
# !python detect.py --source /content/yolov5/Construction/HardHat_2/data/Video/1.mp4 --conf-thres 0.6 --weights /content/yolov5/Construction/HardHat_2/model_results/best_weights/exp6/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/Construction/HardHat_2/model_results/best_weights/exp6/weights/best.pt'], source=/content/yolov5/Construction/HardHat_2/data/Video/1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-250-ga04b49f Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20865057 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/1688) /content/yolov5/Construction/HardHat_2/data/Video/1.mp4: 640x384 (no detections), 74.1ms
# video 1/1 (2/1688) /content/yolov5/Construction/HardHat_2/data/Video/1.mp4: 640x384 (no detections), 18.8ms
# ...

# %%
# !python detect.py --source /content/yolov5/Construction/HardHat_2/data/Video/2.mp4 --conf-thres 0.6 --weights /content/yolov5/Construction/HardHat_2/model_results/best_weights/exp6/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/Construction/HardHat_2/model_results/best_weights/exp6/weights/best.pt'], source=/content/yolov5/Construction/HardHat_2/data/Video/2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-250-ga04b49f Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20865057 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/2087) /content/yolov5/Construction/HardHat_2/data/Video/2.mp4: 640x384 (no detections), 92.1ms
# video 1/1 (2/2087) /content/yolov5/Construction/HardHat_2/data/Video/2.mp4: 640x384 (no detections), 18.8ms
# ...

# %%
# !zip -r /content/video.zip /content/yolov5/runs/detect/
# Out:
#   adding: content/yolov5/runs/detect/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp2/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp2/2.mp4 (deflated 0%)
#   adding: content/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/1.mp4 (deflated 1%)

# %%
from google.colab import files
files.download("/content/video.zip")
